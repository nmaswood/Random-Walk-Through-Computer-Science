# %% [markdown]
# <h1 align="center"> Theoretical Computer Science </h1>

# %% [markdown]
# # The Philosopher and the Computer
#
# ## Space and Time
#
# I took a Computional Complexity in college. On the first day of class, the professor looked at us and asked us as I will ask you:
#
# __What is the difference between time and space?__
#
# <img src="assets/st.jpg" alt="Drawing" style="width: 400px;"/>
#
#
# We all kind of looked at each and said nothing. The professor waited a bit said  __you can reuse space you can't reuse time__.
#
# The reason I asked this question is that during the first class I asked you all: __what is a computer?__ Maybe some of you thought it was a silly question or maybe you thought about it and found it interesting.
#
# ## What is a  Theoritical Computer Scientist
#
#
# These deep, fundamental and often very philosophical questions are asked and answered (sometimes answered) by Theoretical Computer Scienctists. Computer Scientists want to understand the nature of computation and use math to formally prove lemmas about it.
#
# What's interesting to note is that many Theoretical Computer Scientists do not program. They do not have to. Instead they spend most of their time doing math.
#
# While Theoretical Computer Science is a vast field today we will talk about one  (particular important) question in the field: what is practically computable and what is not?

# %% [markdown]
# # What is Computation?
#
# In order to prove interseting things about computation you first need a formal model for what computation is. On the first day we talked about our definition of a computer:
#
# * perform arithmetic / computation
# * read from and write to memory
# * recieve and follow a stream of instructions
#
# These are all characterestic shared by Theoretical Computer Scientist's model of a computer.
#
# This model is called a Turing Machine.
#
# ## Introducing the Turing Machine
#
# <img src="assets/tm.jpg" alt="Drawing" style="width: 400px;"/>
#
# A Turing machine is a hypothetical machine thought of by the mathematician Alan Turing in 1936. Despite its simplicity, the machine can simulate ANY computer algorithm, no matter how complicated it is!
#
# A Turing machine can be thought of an infinitely long tape stretching to the left and the rght. The tape is broken into units where a symbol is written. There is a tape head that moves back and forth on the tape and reads and writes symbols.  It is almost like a mathematician with infinite sheets of paper.
#
# There is also a state diagram which tells the tape how to behave.
#
# <img src="assets/sd.png" alt="Drawing" style="width: 400px;"/>
#
# A tape is given an initial state or program and runs either forever or will eventually accept or reject the program.
#
# __It is said that every computable function is nature is computable with a Turing Machine__
#
# ## Why Bother with the Turing Machine?
#
# Programming languages are different. Computer Aritechtures are different. If mathematicians as a community want to reason about computation in a uniform/standard way they need a uniform/standard way of talking about computation.
#
# ### Write a Program to check if #  of 0s and # of 1s are Equal

# %% [markdown]
# # The Halting Problem
#
# Functions can be input to other functions. See if you can figure out the code right below.
#
# <img src="assets/hm.jpg" alt="Drawing" style="width: 400px;"/>
#
# ```python
#
# def add1(x):
#     return x + 1
#
# def add_hello_to(function):
#     print ("hello!")
#     return function
#
# new_function = add_hello_to_(add1)
# ```
# * What is the Halting Problem?
#
# Now imagine a program for a Turing Machine that given a function and an input will tell you that function will eventually halt on a input.
#
# Why is this an important question:
#
# $$ x^2 + y^2 = z^2$$
# That equation is pythagorems' theorem, many of us learn it in middle school. However, while
#
# $$ x^2 + y^2 = z^2$$
#
# holds for values of $x,y,z$ no such values exist for
#
# $$ x^3 + y^3 = z^3$$
#
# Or any integers greater than $3$. For centuries this was an unsolved problem, recently it has been solved. But imagine the following program.
#
# <img src="assets/fermat.jpg" alt="Drawing" style="width: 400px;"/>
#
#
# ```python
#
# def to_infinity():
#     index=0
#     while 1:
#         yield index
#         index += 1
#
# def fermat(n):
#
#     for x in to_infinity():
#         for y in to_infinity():
#             for z in to_infinity():
#
#                 if x **2 + y **2 == z**2:
#
#                     return x,y,z
#     return 0,0,0
# ```
#
# Because a lot of really practical problems are the halting problem in disguise. A solution to them solves the halting problem.
#
#
# Some problems are instrintically unsolveable without infinite time or undeciadble. This notion of some problems being unsolvable is super important in Computer Science.
#
# ## Proof
#
#
# <img src="assets/proof.jpg" alt="Drawing" style="width: 400px;"/>

# %% [markdown]
# # NP vs P
#
# <img src="assets/np.png" alt="Drawing" style="width: 400px;"/>
#
# # What is P vs NP
#
# The P versus NP problem is a major unsolved problem in computer science. Informally speaking, it asks whether every problem whose solution can be quickly verified by a computer can also be quickly solved by a computer.
#
# # NP
#
# NP (which stands for nondeterministic polynomial time) is the set of problems whose solutions can be verified in polynomial time. But as far as anyone can tell, many of those problems take exponential time to solve. Perhaps the most famous exponential-time problem in NP, for example, is finding prime factors of a large number. Verifying a solution just requires multiplication, but solving the problem seems to require systematically trying out lots of candidates.
#
# So the question “Does P equal NP?” means “If the solution to a problem can be verified in polynomial time, can it be found in polynomial time?” Part of the question’s allure is that the vast majority of NP problems whose solutions seem to require exponential time are what’s called NP-complete, meaning that a polynomial-time solution to one can be adapted to solve all the others. And in real life, NP-complete problems are fairly common, especially in large scheduling tasks.
#
# ## Traveling Salesman
#
# The most famous NP-complete problem, for instance, is the so-called traveling-salesman problem: given N cities and the distances between them, can you find a route that hits all of them but is shorter than … whatever limit you choose to set?
#
#
# ## NP == P?
#
# Given that P probably doesn’t equal NP, however — that efficient solutions to NP problems will probably never be found — what’s all the fuss about? Michael Sipser, the head of the MIT Department of Mathematics and a member of the Computer Science and Artificial Intelligence Lab’s Theory of Computation Group (TOC), says that the P-versus-NP problem is important for deepening our understanding of computational complexity.
#
# ## Crytography
#
# “A major application is in the cryptography area,” Sipser says, where the security of cryptographic codes is often ensured by the complexity of a computational task. The RSA cryptographic scheme, which is commonly used for secure Internet transactions — and was invented at MIT — “is really an outgrowth of the study of the complexity of doing certain number-theoretic computations,” Sipser says.
