# %% [markdown]
# <h1 align="center">Lesson 1: The Journey's Beginning</h1>
#
#
#
# # 1  Why are we here?
#
#
# You could just easily have been at the beach today, but instead you are here learning how to code.
#
# <img src="assets/beach.jpg" alt="Drawing" style="width: 400px;"/>
#
# Well $\ldots$ you made the right decesion! Programming is an immensely useful skill. It will help your job prospects, your critical thinking skills and will allow to do tons of cool stuff. With the ability to program you can $\ldots$
#
# ## 1.1 Cool Stuff You Will (One Day) Be Able to Do
#
# * Build and understand cool applications like $YouTube$, $Facebook$ and $Snapchat$
# * [Teach cars to drive themselves](http://selfdrivingcars.mit.edu/)
# * [Make millions of dollars on the stock market](https://www.quantopian.com/home)
# * [Program Neural Networks to write poetry for you](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
# * And tons and tons of other stuff.
#
# <img src="assets/code.jpg" alt="Drawing" style="width: 400px;"/>
#
# In this course you should expect you learn the fundamentals of programming (in Python) and to be exposed to several topics in Computer Science. While we can't teach you everything in these two weeks, you should walk away as a confident and eager burgeoning Computer Scientist.
#
# ## 1.2 Course Etiquette
#
# This is a very short course, so in order to make sure you get something out of it you'll have to do the following
#
# <img src="assets/question.jpg" alt="Drawing" style="width: 400px;"/>
#
# * Ask questions. A lot of them, whether in class or outside of class.
# * Do the exercises assigned. __YOU WILL ONLY LEARN PROGRAMMING BY DOING IT YOURSELF__
# * Provide feedback for me, if something is unclear or not as you like, __please let me know__
#     * If things are too easy tell me. If things are too hard tell me.
# * Have Fun! Programming is a lively field, do yourself a favor and enjoy it!
#
# ---

# %% [markdown]
# # 2.0  Big Questions
#
# Before we step into programming specifics we are going to pause and look into what a computer is and how it works.
#
# ## 2.1 What is a Computer?
#
# Nowadays there are computers everywhere: the cellphone in your pocket, the smartwatch on your wrist and of course the MacBook on your table. What do these three devices have in common? What actually makes them a computer, persay? Is a calculator a computer?
#
# <img src="assets/mainframe.jpg" alt="Drawing" style="width: 400px;"/>
#
# __For reasons that will be come clear as we move on I will argue that a computer is any device that does the three following things:__
#
# * Perform Arithmetic
# * Read and Write Data
# * Recieve and Execute Instructions
#
# As strange as it may seem, all the complex, amazing things computers do today $-$ calculating the trajectory of rockets being sent to the moon, streaming you a cat video from YouTube or translating English to French $-$ are all done by combinations of these three things.
#
# A real, modern day computer works through a processor. The processor has aj limited set of instructions it can perform on values such as addition, multiplication, etc. It combines these simple instructions to do arbitraryly complex tasks.
#
# <img src="assets/opcodes.PNG" alt="Drawing" style="width: 400px;"/>
#
#
# We'll talk about binary and how computers store and process information later.
#
# ## 2.2 What is a Computer Program ?
#
# __A computer program a series of an instructions that tells a computer what to do__
#
# What do these "programs" looks like?
#
# Let's say you are a football player and recieving a stream of instructions. It might look like this:
#
# <img src="assets/football.jpg" alt="Drawing" style="width: 400px;"/>
#
#
# ```
# while you_have_the_ball:
#     dribble
#     if team_mate_open:
#         pass_the_ball
#         you_have_the_ball = false
#
#     if goal_is_open:
#         shoot
#         if you_score:
#             celebrate
#         else:
#             run_back_to_your_side
# ```
#
# Another example. You work at NASA and want to send an astronaut to space. You might write a program like this:
#
#
# <img src="assets/launch.jpg" alt="Drawing" style="width: 400px;"/>
#
#
# ```
# if astronaut_ready_to_launch and boosters_ready:
#
#     1. alert mission command
#     2. alert astronauts
#     3. wait sixty seconds
#     4. intiate boosters
#     5. blast off
#
# else:
#
#     do not blast off
# ```
#
# The only this is that for a computer to understand these instructions I have to write it in a programming language.
#
# ## 2.2.1 What is a Programming Language?
#
# ___A vocabulary and set of grammatical rules for instructing a computer to perform specific tasks___
#
# Ok, what?
#
# Let's put it this way. You can more or less say the same types of things in two different spoken languags like Latin and Arabic. Sometimes, a langauge can be better suited for a certain task like maybe, Arabic for poetry, or Latin for modern day medical terminology.
#
# Programming languages are the same. There are many languages out there and they are all slightly different, but all they are equivalent in their ability to convey the same basic notions.
#
# For example, the following Python 3 program tells the computer to `print` "Hello world"
#
# ```python
# print ("Hello world")```
#
# The following is a `C` Program that does the same thing
#
# ```C
# #include<stdio.h>
#
# main(){
#     printf("Hello World");
# }
# ```
#
#
# The following is a "python program" does not do anything as it does not conform to the rules of python
#
# ```python
# print ("hello
# ```
#
# The computer does not know how to intepret the program as it expects the quotes and paranthesis to be closed.

# %% [markdown]
# ### 2.2.2 How does the the computer understand a language?
#
# Ok, so obviously computers do not speak  and understand English ( at least not yet.) So, how does your computer know what you mean when you tell it to `print` something?
#
# There are many levels of abstraction going on from when you type
#
# ```python
# print ("hello world")
# ```
#
# to actually seeing `hello world` appear on your screen. We won't go into all of that right now.
#
# What you need to know now is that that computers understand and work in zeros and ones.
#
# <img src="assets/bits.jpg" alt="Drawing" style="width: 400px;"/>
# ___

# %% [markdown]
# # 3. Binary : To be on or to not be on
#
# When you open up a word process like Microsoft Word and write your History. How do you think that information is stored on your computer when you type it? Do the words __Hannibal__ literally get etched into sillicon somewhere in your computer?
#
# <img src="assets/hannibal.png" alt="Drawing" style="width: 400px;"/>
#
#
# No. As you are typing information into the computer it is being converted from English or French or Whatever into a series of $0s$ and $1s$ These $0s$ and $1s$ correspond to little transistors in your computer being flipped on or off. These $0s$ and $1s$ can be used to represent arbitrary information
#
# ## 3.1 A simple example
#
# __How many chicks do you count in the following picture__
#
# <img src="assets/chicks.png" alt="Drawing" style="width: 400px;"/>
#
# Most (all?) people would say :
#
# __5__
#
#
# However if you were a computer you would say:
#
# ___101___
#
# Both answers are right
#
#
# __This is because you can represent the same number in different number systems.__
#
# For example take the number ___2048___
#
# <img src="assets/2048.jpg" alt="Drawing" style="width: 800px;height:400px"/>
#
#
# In base ten this number is represented as __2048__ because
#
#
# \begin{align}
# 2048 &= 2 \times  1000 + 0 \times 100 + 4 \times 10 + 8 \times 1\\
# 2048 &= 2 \times  10^3 + 0 \times 10^2 + 4 \times 10^1 + 8 \times 10^0\\
# \end{align}
#
# In base two this number is represented as __100000000000__ because
#
# \begin{align}
# 2048 &= 1 \times 2^{11} + 0 \times 2^{10}  + \ldots + 0 \times  2^{0}
# \end{align}
#
# ## 3.2 Definition of Binary
#
# Use of the base-2 number system is referred to as __binary__. Binary uses two mutually exclusive states to represent information. A binary number is made up of elements called bits where each bit can be in one of the two possible states. Generally, we represent them with the numerals 1 and 0. We also talk about them being true and false. Electrically, the two states might be represented by high and low voltages or some form of switch turned on or off.
#
# ## 3.3 Uses of Binary
#
#
# ### Math
#
# Computers store information in binary and perform arithmetic on numbers in binary form. For example look how one can add two numbers together in binary.
#
#
# <img src="assets/add.png" alt="Drawing" style="width: 800px;height:400px"/>
#
# ### Letters
#
# Binary can also be used to represent, letters and characters. An encoding system called ASCII is used to map between simple characters and numbers represented in binary.
#
# <img src="assets/ascii.png" alt="Drawing" style="width: 800px;height:400px"/>
#
# ### Colors
#
# Numbers in the form of binary can also be used to represent colors. The image on your computer is made from millions of tiny blocks called pixels (picture elements). Each one of these is effectively a separate red, blue, or green light that can be switched on or off very rapidly to make the moving color picture.
#
# Numbers ranging from 1 to 255 control the intensity of each light and thus different number combinations referring the intensity of the RGB lights can be used to make images.
#
#
# ## 3.4 Bytes
#
# Computers store data in binary in units called bytes. A byte is an 8-bit unit.
# ___

# %% [markdown]
# # 4. Our First Program: Hello World
#
#
# ## 4.1 Hello!
#
# Find the `python` interpreter on your computer.
#
# Type in the following
#
# ```python
# print ("hello world")
# print ("I'm in Tunisia, hooray")
# ```
#
# Congradulations! Once you have done that you have written your first "computer program." It isn't very sophiscated but everyone starts somewhere.
#
# <img src="assets/cele.jpg">
#
# Congradulations! you have written your first "computer program." It isn't very sophiscated but everyone starts somewhere.
#
#
# ## 4.2 Do the Math
#
# Try out some simple operations.
#
# ```python
# print (2 + 2) # 2 + 2
# print (10 - 2) # 10 -2
# print (3 * 4)  # 3 * 4
# print (10 / 2) # 10 / 2
# print (2 ** 3 )  # 2 ^ 3
# print ((1 + 1) * 2)
# print (3 - (4 + 1) ** 2) - (1 - 3 * 3)
# ```
# Try out some simple operations.
#
# ## 4.3  Comments
#
# Sometimes you want to leave a message in your code to yourself or the next programmer you see. This done through the use of comments. These areas of your code you do not want the computer to intrepret as code.
#
# In python anything on a line coming after a `#` will be interpreted as a comment.
#
# ```python
# print ("this will get printed")
# # print ("this will not get printed")
# ```
#
# If you want a multiline comment wrap your text in triple quotes
# ```python
# print ("this will print")
#
# """
# print ("this  will not print")
# print ("this  wont either")
# """
# ```

# %% [markdown]
# # 5 What's your type?
#
#
# <img src="assets/dog.jpg" alt="Drawing" style="width: 400px;"/>
#
# If I was to ask you what is $2 + 2$ you would have no problem telling me. However what if I asked you the value of $2 + \text{ "dog" }$ you would have no clue what was I talking about. That's because addition as we know it is an operator between two numbers.
#
# Similarily, in language, you have a verb that you conjugate for different forms. If I asked to conjugate the word __walk__ in past tense, you would tell me __walked__. If I told you to conjugate the number __4__ in past tense, that would make no sense.
#
#
# __ In computer science you have functions or operators that act on types. Before the computer executes your code it will ensure that all the types match up correctly with respect to operators you are trying to use__
#
# ## 5.1 TypeError
#
# Try typing the following into your interpreter
#
# ```python
# 1 + "1"
# ```
#
# You should get the following error
# ```python
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# ```
#
# This is because you are giving the `+` operator which is expecting two numbers a number and a string.
#
# A __number__ is a well ... a numeric of the form `1.0` or `1234` or `(1234 + 1234)`
#
# A __string__ is a sequence of characters. We denote a string in Python by wrapping text in quotations.
#
# `12345` is a number.
# `"12345"` is a string.
#
# We will encounter more types in the future, but these are the two most fundamental.
#
#
# ## 5.2 Boolean Types
#
# __boolean__ which are values that are `True` or `False`. They are extremely important and common.
#
# * Booleans are used for testing equality
#     * __SIDE NOTE__ `==` is the equality operator and checks for equality between two objects
#
# ```python
# 2 == 2 # Returns True
# 234 == 2340 / 10 # Returns True
# "apple" == "orange" # Returns False
# ```
#
# * Booleans are used for control flow: `if` and `while` statements.
# ```python
# if 36 * 3 == 12  * 6:
#     print ("wow they are equal")
# else:
#     print ("they are not equal :( ")
# ```
#
# * Boolean Logic
#     * Is a form of reasoning about booleans through a series of operators
#
# <img src="assets/bool.png" alt="Drawing" style="width: 400px;"/>

# %%
type(1), type("1")
# Out:
# (int, str)

# %% [markdown]
# # 6 Variables
#
#
# pay attention to this shit later
# equal sign is an assignment of a value to a variable
# name
# pi = 3.14159
# pi_approx = 22/7
#  value stored in computer memory
#  an assignment binds name to value
#
#
#  why give names to values of expressions?
#  to reuse names instead of values
#
#
# In Computer Science you will want to access and updates __values__ while you perform calculations or solve problems.
#
#
# # 6.1 Example One
#
# Let's say you are a employee at a  small grocery store.
# Your employer wants you to keep track of how many people entered the store during the day.
#
# <img src="assets/g.jpg" alt="Drawing" style="width: 400px;"/>
#
#
# Unless you have a really good memory, you'll keep track of the amount of people coming into the store by writing it down.
#
# <img src="assets/Tally.png" alt="Drawing" style="width: 400px;"/>
#
# You have a __value that you are accessing and updating__
#
# In Computer Science the same concept is present in __variables__ which is stored reference to a value.
#
# Let's look at the previous example in code:
#
# ```python
#
# amount_of_customers_in_store = 0
# amount_of_customers_in_store = amount_of_customers_in_store + 1
# amount_of_customers_in_store = amount_of_customers_in_store + 2
# amount_of_customers_in_store = amount_of_customers_in_store + 1
# ```

# %% [markdown]
# # Review
#
#
# * What Is a computer?
#     * What does a computer need to do?
# * What is Programming Language?
#     * What does a computer need to do?
# * How does a Computer store Information?
# * What is Binary?
# * What are types?
# * What are variables?

# %% [markdown]
# # Installing python
#
#
# http://introtopython.org/programming_environment.html
